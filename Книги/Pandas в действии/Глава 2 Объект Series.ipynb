# %% [markdown]
# <a href="https://colab.research.google.com/github/CatMolnia/Studies/blob/main/%D0%9A%D0%BD%D0%B8%D0%B3%D0%B8/Pandas%20%D0%B2%20%D0%B4%D0%B5%D0%B9%D1%81%D1%82%D0%B2%D0%B8%D0%B8/%D0%93%D0%BB%D0%B0%D0%B2%D0%B0%202%20%D0%9E%D0%B1%D1%8A%D0%B5%D0%BA%D1%82%20Series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# """---2. ОБОЪЕКТ SERIES---"""
#
# """---2.1 ОБЗОР SERIES---"""
#
# """---2.1.3. Пользовательские индексы для Series---"""

# %%
import pandas as pd
import numpy as np

# %%
ice_cream_flavors = [
  "Chocolate",
  "Vanilla",
  "Strawberry",
  "Rum Raisin",
]

pd.Series(ice_cream_flavors) # создание объекта Series
# Out:
# 0     Chocolate
# 1       Vanilla
# 2    Strawberry
# 3    Rum Raisin
# dtype: object

# %%
days_of_week = ("Monday", "Wednesday", "Friday", "Saturday")

# %%
pd.Series(ice_cream_flavors, days_of_week)
pd.Series(data = ice_cream_flavors, index = days_of_week)
# Out:
# Monday        Chocolate
# Wednesday       Vanilla
# Friday       Strawberry
# Saturday     Rum Raisin
# dtype: object

# %%
bunch_of_bools = [True, False, False]
pd.Series(bunch_of_bools)
# Out:
# 0     True
# 1    False
# 2    False
# dtype: bool

# %%
stock_prices = [985.32, 950.44]
time_of_day = ["Open", "Close"]
pd.Series(data = stock_prices, index = time_of_day)
# Out:
# Open     985.32
# Close    950.44
# dtype: float64

# %%
lucky_numbers = [4, 8, 15, 16, 23, 42]
pd.Series(lucky_numbers)
# Out:
# 0     4
# 1     8
# 2    15
# 3    16
# 4    23
# 5    42
# dtype: int64

# %%
lucky_numbers = [4, 8, 15, 16, 23, 42]
pd.Series(lucky_numbers, dtype = "float") # принудительно меняем формат передаваемых данных
# Out:
# 0     4.0
# 1     8.0
# 2    15.0
# 3    16.0
# 4    23.0
# 5    42.0
# dtype: float64

# %% [markdown]
# """---2.1.4. Создание объекта Series
# с пропущенными значениями---""

# %%
temperatures = [94, 88, np.nan, 91] # создаем пропущенное значение в объекте Series
pd.Series(temperatures)
# Out:
# 0    94.0
# 1    88.0
# 2     NaN
# 3    91.0
# dtype: float64

# %% [markdown]
# """---2.2 СОЗДАНИЕ ОБЪЕКТОВ SERIES НА ОСНОВЕ ОБЪЕКТА ЯЗЫКА PYTHON---"""

# %%
# ассоциативный массив (словарь) (ключ: значение)
calorie_info = {
  "Cereal": 125,
  "Chocolate Bar": 406,
  "Ice Cream Sundae": 342,
}

diet = pd.Series(calorie_info)

diet
# Out:
# Cereal              125
# Chocolate Bar       406
# Ice Cream Sundae    342
# dtype: int64

# %%
# кортежи
pd.Series(data = ("Red", "Green", "Blue")) # кортеж (неизменяемый список)
# Out:
# 0      Red
# 1    Green
# 2     Blue
# dtype: object

# %%
# кортежи в списке
rgb_colors = [(120, 41, 26), (196, 165, 45)] # кортежи, заключенные в список
pd.Series(data = rgb_colors)
# Out:
# 0     (120, 41, 26)
# 1    (196, 165, 45)
# dtype: object

# %%
# множество
my_set = {"Ricky", "Bobby"}
pd.Series(list(my_set)) # преобразуем множество в список (иначе будет ошибка)
# Out:
# 0    Bobby
# 1    Ricky
# dtype: object

# %%
# объект ndarray библиотеки NymPy
random_data = np.random.randint(1, 101, 10)
random_data
# Out:
# array([30,  6, 37, 26, 95, 28, 19, 90, 17, 77])

# %%
pd.Series(random_data) # передаем в Series объект ndarray
# Out:
# 0    30
# 1     6
# 2    37
# 3    26
# 4    95
# 5    28
# 6    19
# 7    90
# 8    17
# 9    77
# dtype: int64

# %% [markdown]
# """---2.3 АТРИБУТЫ SERIES---"""

# %%
diet = {
    'Cereal': 125,
    'Chocolate Bar': 406,
    'Ice Cream Sundae': 342,
}

# %%
np.array(diet.values()) # обращаемся к объекту ndarray, в котором храняться значения
# Out:
# array(dict_values([125, 406, 342]), dtype=object)

# %%
pd.Series(diet).index # обращаемся к Series для определения индекса
# Out:
# Index(['Cereal', 'Chocolate Bar', 'Ice Cream Sundae'], dtype='object')

# %%
pd.Series(diet).dtype # обращаемся к Series для определения типа данных
# Out:
# dtype('int64')

# %%
pd.Series(diet).size # обращаемся к Series для определения количества элементов
# Out:
# 3

# %%
pd.Series(diet).shape # обращаемся к Series для определения формы данных
# Out:
# (3,)

# %%
pd.Series(diet).is_unique # обращаемся к Series для определения уникальности данных
# Out:
# True

# %%
pd.Series(data=[3, 2, 1]).is_monotonic_decreasing # обращаемся к Series для определения монотонности данных (убывание)
# Out:
# True

# %%
pd.Series(data=[1, 3, 2]).is_monotonic_increasing # обращаемся к Series для определения монотонности данных (возрастание)
# Out:
# False

# %% [markdown]
# """---2.4 ВОЗВРЩЕНИЕ ПЕРВОЙ И ПОСЛЕДНЕЙ СТРОК---"""

# %%
values = range(0, 500, 5)
pd.Series(data=values)
# Out:
# 0       0
# 1       5
# 2      10
# 3      15
# 4      20
#      ...
# 95    475
# 96    480
# 97    485
# 98    490
# 99    495
# Length: 100, dtype: int64

# %%
nums = pd.Series(data=values)

# %%
nums.head(3) # возвращаем первые 3 строки
# Out:
# 0     0
# 1     5
# 2    10
# dtype: int64

# %%
nums.tail(3) # возвращаем последние 3 строки
# Out:
# 97    485
# 98    490
# 99    495
# dtype: int64

# %% [markdown]
# """---2.5 МАТЕМАТИЧЕСКИЕ ОПЕРАЦИИ---"""
#
# """---2.5.1. Статистические операции---"""

# %%
numbers = pd.Series([1, 2, 3, np.nan, 4, 5])
numbers
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
numbers.count() # подсчет непустых значений
# Out:
# np.int64(5)

# %%
numbers.sum() # сумма непустых значений
# Out:
# np.float64(15.0)

# %%
numbers.sum(skipna = False) # определение суммы значений с пропущенными значениями
# Out:
# np.float64(nan)

# %%
numbers.sum(min_count = 3) # определение суммы значений с минимальным количеством непустых значений
# Out:
# np.float64(15.0)

# %%
numbers.product() # перемнажаем все значения Series
# Out:
# np.float64(120.0)

# %%
numbers.product(min_count=3)
# Out:
# np.float64(120.0)

# %%
numbers.cumsum() # нарастающая сумма
# Out:
# 0     1.0
# 1     3.0
# 2     6.0
# 3     NaN
# 4    10.0
# 5    15.0
# dtype: float64

# %%
numbers.cumsum(skipna = False) # рассчет нарастающей суммы до первого пустого знаяниея
# Out:
# 0    1.0
# 1    3.0
# 2    6.0
# 3    NaN
# 4    NaN
# 5    NaN
# dtype: float64

# %%
numbers.pct_change() # подтягивает вместо nan последнее (предыдущее nan) допустимое значение (также можно через 'pad' или 'ffill')
# Out:
# /tmp/ipykernel_1060/2024929600.py:1: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   numbers.pct_change() # подтягивает вместо nan последнее (предыдущее nan) допустимое значение (также можно через 'pad' или 'ffill')
# 0         NaN
# 1    1.000000
# 2    0.500000
# 3    0.000000
# 4    0.333333
# 5    0.250000
# dtype: float64

# %%
numbers.pct_change(fill_method="bfill") # подтягивает вместо nan следуюшее (первое после nan) допустимое значение (также можно через 'bfill' или 'backfill')
# Out:
# /tmp/ipykernel_1060/3584170859.py:1: FutureWarning: The 'fill_method' keyword being not None and the 'limit' keyword in Series.pct_change are deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   numbers.pct_change(fill_method="bfill") # подтягивает вместо nan следуюшее (первое после nan) допустимое значение (также можно через 'bfill' или 'backfill')
# 0         NaN
# 1    1.000000
# 2    0.500000
# 3    0.333333
# 4    0.000000
# 5    0.250000
# dtype: float64

# %%
numbers.mean() # вывод среднего значения (nan не учитывается)
# Out:
# np.float64(3.0)

# %%
numbers.median() # вывод значения, распопложенного посередине в отсортированном списке значений Series (nan не учитывается)
# Out:
# 3.0

# %%
numbers.std() # вывод стандартного отклонения (мера отклонения данных от среднего значения)
# Out:
# 1.5811388300841898

# %%
numbers.max() # извлекаем максимальное значение
# Out:
# 5.0

# %%
numbers.min() # извлекаем минимальное значение
# Out:
# 1.0

# %%
animals = pd.Series(["koala", "aardvark", "zebra"])
animals
# Out:
# 0       koala
# 1    aardvark
# 2       zebra
# dtype: object

# %%
animals.max() # ближайшая к концу алфавита буква
# Out:
# 'zebra'

# %%
animals.min() # ближайшая к началу алфавита буква
# Out:
# 'aardvark'

# %%
numbers.describe() # вся сводная информация об объекте Series
# Out:
# count    5.000000
# mean     3.000000
# std      1.581139
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000
# dtype: float64

# %%
numbers.sample(3) # извлекаем случайный набор значений из объекта Series
# Out:
# 1    2.0
# 5    5.0
# 0    1.0
# dtype: float64

# %%
authors = pd.Series(
  ["Hemingway", "Orwell", "Dostoevsky", "Fitzgerald", "Orwell"]
)
authors.unique() # получаем неповторяющиеся значения из объекта
# Out:
# array(['Hemingway', 'Orwell', 'Dostoevsky', 'Fitzgerald'], dtype=object)

# %%
authors.nunique() # возвращаем количество уникальных значений
# Out:
# 4

# %% [markdown]
# """---2.5.2. Арифметические операции---"""

# %%
s1 = pd.Series(data = [5, np.nan, 15], index = ["A", "B", "C"])
s1
# Out:
# A     5.0
# B     NaN
# C    15.0
# dtype: float64

# %%
s1 + 3 # операция сложения
# Out:
# A     8.0
# B     NaN
# C    18.0
# dtype: float64

# %%
s1.add(3) # аналог операция сложения
# Out:
# A     8.0
# B     NaN
# C    18.0
# dtype: float64

# %%
s1 - 5 # операция вычитания
s1.sub(5) # аналог
s1.subtract(5) # аналог
# Out:
# A     0.0
# B     NaN
# C    10.0
# dtype: float64

# %%
s1 * 2 # операция умножения
s1.mul(2) # аналог
s1.multiply(2) # аналог
# Out:
# A    10.0
# B     NaN
# C    30.0
# dtype: float64

# %%
s1 / 2 # операция деления
s1.div(2) # аналог
s1.divide(2) # аналог
# Out:
# A    2.5
# B    NaN
# C    7.5
# dtype: float64

# %%
s1 // 4 # целочисленное деление (округление вниз)
s1.floordiv(4) # аналог
# Out:
# A    1.0
# B    NaN
# C    3.0
# dtype: float64

# %%
s1 % 3
s1.mod(3)
# Out:
# A    2.0
# B    NaN
# C    0.0
# dtype: float64

# %% [markdown]
# """---2.5.3. Транслирование---"""

# %%
s1 = pd.Series([1, 2, 3], index = ["A", "B", "C"])
s2 = pd.Series([4, 5, 6], index = ["A", "B", "C"])
s1 + s2
# Out:
# A    5
# B    7
# C    9
# dtype: int64

# %%
s1 = pd.Series(data = [3, 6, np.nan, 12])
s2 = pd.Series(data = [2, 6, np.nan, 12])
s1 == s2 # проверяем два объекта на равенство
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
s1 != s2 # проверяем два объекта на неравенство
s1.ne(s2) # аналог
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
s1 = pd.Series(
  data = [5, 10, 15], index = ["A", "B", "C"]
)
s2 = pd.Series(
  data = [4, 8, 12, 14], index = ["B", "C", "D", "E"]
)
s1 + s2
# Out:
# A     NaN
# B    14.0
# C    23.0
# D     NaN
# E     NaN
# dtype: float64

# %% [markdown]
# """---2.6. ПЕРЕДАЧА ОБЪЕКТОВ SERIES ВСТРОЕННЫМ ФУНКЦИЯМ ЯЗЫКА PYTHON---"""

# %%
cities = pd.Series(data=["San Francisco", "Los Angeles", "Las Vegas", np.nan])
len(cities) # возвращаем количество строк в объекте, включая nan
# Out:
# 4

# %%
type(cities) # определям класс, к которому относится объект
# Out:
# pandas.core.series.Series

# %%
dir(cities) # возвращаем список атрибутов и методов объекта

# %%
list(cities) # создаем из объекта Series список
# Out:
# ['San Francisco', 'Los Angeles', 'Las Vegas', nan]

# %%
dict(cities) # получаем ассоциативный массив (с индексами)
# Out:
# {0: 'San Francisco', 1: 'Los Angeles', 2: 'Las Vegas', 3: nan}

# %%
cities
# Out:
# 0    San Francisco
# 1      Los Angeles
# 2        Las Vegas
# 3              NaN
# dtype: object

# %%
"Las Vegas" in cities # проверяем вхождение условия в индексе
# Out:
# False

# %%
2 in cities
# Out:
# True

# %%
"Las Vegas" in cities.values # проверяем вхождение условия в значениях
# Out:
# True

# %%
100 not in cities # проверяем на невхождение условия в индексе
# Out:
# True

# %%
"Paris" not in cities.values # проверяем на невхождение условия в значениях
# Out:
# True

# %% [markdown]
# """---2.7. УПРАЖНЕНИЯ---"""

# %%
superheroes = [
    "Batman",
    "Superman",
    "Spider-man",
    "Iron Man",
    "Capitan America",
    "Wonder Woman"
]

strength_levels = (100, 120, 90, 95, 110, 120)

# %%
o1 = pd.Series(superheroes)
o1
# Out:
# 0             Batman
# 1           Superman
# 2         Spider-man
# 3           Iron Man
# 4    Capitan America
# 5       Wonder Woman
# dtype: object

# %%
o2 = pd.Series(strength_levels)
o2
# Out:
# 0    100
# 1    120
# 2     90
# 3     95
# 4    110
# 5    120
# dtype: int64

# %%
heroes = pd.Series(data=strength_levels, index=superheroes)
heroes
# Out:
# Batman             100
# Superman           120
# Spider-man          90
# Iron Man            95
# Capitan America    110
# Wonder Woman       120
# dtype: int64

# %%
heroes.head(2)
# Out:
# Batman      100
# Superman    120
# dtype: int64

# %%
heroes.tail(4)
# Out:
# Spider-man          90
# Iron Man            95
# Capitan America    110
# Wonder Woman       120
# dtype: int64

# %%
heroes.nunique()
# Out:
# 5

# %%
heroes.mean()
# Out:
# np.float64(105.83333333333333)

# %%
heroes.max()
# Out:
# 120

# %%
heroes.min()
# Out:
# 90

# %%
heroes * 2
# Out:
# Batman             200
# Superman           240
# Spider-man         180
# Iron Man           190
# Capitan America    220
# Wonder Woman       240
# dtype: int64

# %%
dict(heroes)
# Out:
# {'Batman': np.int64(100),
#  'Superman': np.int64(120),
#  'Spider-man': np.int64(90),
#  'Iron Man': np.int64(95),
#  'Capitan America': np.int64(110),
#  'Wonder Woman': np.int64(120)}
