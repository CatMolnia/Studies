# %% [markdown]
# <a href="https://colab.research.google.com/github/CatMolnia/Studies/blob/main/%D0%9A%D0%BD%D0%B8%D0%B3%D0%B8/Pandas%20%D0%B2%20%D0%B4%D0%B5%D0%B9%D1%81%D1%82%D0%B2%D0%B8%D0%B8/%D0%93%D0%BB%D0%B0%D0%B2%D0%B0%205.%20%D0%A4%D0%B8%D0%BB%D1%8C%D1%82%D1%80%D0%B0%D1%86%D0%B8%D1%8F%20%D0%BE%D0%B1%D1%8A%D0%B5%D0%BA%D1%82%D0%BE%D0%B2%20%D0%B2%20DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# """---5. ФИЛЬТРАЦИЯ ОБЪЕКТОВ DataFrame---"""
#
# """---5.1 ОПТИМИЗАЦИЯ ПАМЯТИ, ИСПОЛЬЗУЕМОЙ НАБОРОМ ДАННЫХ---"""

# %%
import pandas as pd

# %%
pd.read_csv("employees.csv")
# Out:
#      First Name  Gender Start Date    Salary   Mgmt          Team
# 0       Douglas    Male     8/6/93       NaN   True     Marketing
# 1        Thomas    Male    3/31/96   61933.0   True           NaN
# 2         Maria  Female        NaN  130590.0  False       Finance
# 3         Jerry     NaN     3/4/05  138705.0   True       Finance
# 4         Larry    Male    1/24/98  101004.0   True            IT
# ...         ...     ...        ...       ...    ...           ...
# 996     Phillip    Male    1/31/84   42392.0  False       Finance
# 997     Russell    Male    5/20/13   96914.0  False       Product
# 998       Larry    Male    4/20/13   60500.0  False  Business Dev
# 999      Albert    Male    5/15/12  129949.0   True         Sales
# 1000        NaN     NaN        NaN       NaN    NaN           NaN
#
# [1001 rows x 6 columns]

# %%
employees = pd.read_csv("employees.csv", parse_dates = ["Start Date"])

employees
# Out:
# /tmp/ipykernel_4248/137010310.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   employees = pd.read_csv("employees.csv", parse_dates = ["Start Date"])
#      First Name  Gender Start Date    Salary   Mgmt          Team
# 0       Douglas    Male 1993-08-06       NaN   True     Marketing
# 1        Thomas    Male 1996-03-31   61933.0   True           NaN
# 2         Maria  Female        NaT  130590.0  False       Finance
# 3         Jerry     NaN 2005-03-04  138705.0   True       Finance
# 4         Larry    Male 1998-01-24  101004.0   True            IT
# ...         ...     ...        ...       ...    ...           ...
# 996     Phillip    Male 1984-01-31   42392.0  False       Finance
# 997     Russell    Male 2013-05-20   96914.0  False       Product
# 998       Larry    Male 2013-04-20   60500.0  False  Business Dev
# ...

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    object
#  2   Start Date  999 non-null    datetime64[ns]
#  3   Salary      999 non-null    float64
#  4   Mgmt        933 non-null    object
#  5   Team        957 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 47.1+ KB

# %% [markdown]
# """---5.1.1 Преобразование типов данных с помощью метода astype---"""

# %%
employees["Mgmt"].astype(bool) # создали объект Series. значение NaN преобразовалось в True.
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 996     False
# 997     False
# 998     False
# 999      True
# 1000     True
# Name: Mgmt, Length: 1001, dtype: bool

# %%
employees["Mgmt"] = employees["Mgmt"].astype(bool) # это уже объект DataFrame

# %%
employees.tail()
# Out:
#      First Name Gender Start Date    Salary   Mgmt          Team
# 996     Phillip   Male 1984-01-31   42392.0  False       Finance
# 997     Russell   Male 2013-05-20   96914.0  False       Product
# 998       Larry   Male 2013-04-20   60500.0  False  Business Dev
# 999      Albert   Male 2012-05-15  129949.0   True         Sales
# 1000        NaN    NaN        NaT       NaN   True           NaN

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    object
#  2   Start Date  999 non-null    datetime64[ns]
#  3   Salary      999 non-null    float64
#  4   Mgmt        1001 non-null   bool
#  5   Team        957 non-null    object
# dtypes: bool(1), datetime64[ns](1), float64(1), object(3)
# memory usage: 40.2+ KB

# %%
employees["Salary"].fillna(0).astype(int).tail()
# Out:
# 996      42392
# 997      96914
# 998      60500
# 999     129949
# 1000         0
# Name: Salary, dtype: int64

# %%
employees["Salary"] = employees["Salary"].fillna(0).astype(int)

# %%
employees.nunique()
# Out:
# First Name    200
# Gender          2
# Start Date    971
# Salary        995
# Mgmt            2
# Team           10
# dtype: int64

# %%
employees["Gender"].astype("category")
# Out:
# 0         Male
# 1         Male
# 2       Female
# 3          NaN
# 4         Male
#          ...
# 996       Male
# 997       Male
# 998       Male
# 999       Male
# 1000       NaN
# Name: Gender, Length: 1001, dtype: category
# Categories (2, object): ['Female', 'Male']

# %%
employees["Gender"] = employees["Gender"].astype("category")

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    category
#  2   Start Date  999 non-null    datetime64[ns]
#  3   Salary      1001 non-null   int64
#  4   Mgmt        1001 non-null   bool
#  5   Team        957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](1), int64(1), object(2)
# memory usage: 33.5+ KB

# %%
employees["Team"] = employees["Team"].astype("category")

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    category
#  2   Start Date  999 non-null    datetime64[ns]
#  3   Salary      1001 non-null   int64
#  4   Mgmt        1001 non-null   bool
#  5   Team        957 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](1), int64(1), object(1)
# memory usage: 27.0+ KB

# %% [markdown]
# """---5.2 ФИЛЬТРАЦИЯ ПО ОДНОМУ УСЛОВИЮ---"""

# %%
employees[employees["First Name"] == "Maria"] # извлекаем все записи True по условию
# Out:
#     First Name  Gender Start Date  Salary   Mgmt          Team
# 2        Maria  Female        NaT  130590  False       Finance
# 198      Maria  Female 1990-12-27   36067   True       Product
# 815      Maria     NaN 1986-01-18  106562  False            HR
# 844      Maria     NaN 1985-06-19  148857  False         Legal
# 936      Maria  Female 2003-03-14   96250  False  Business Dev
# 984      Maria  Female 2011-10-15   43455  False   Engineering

# %%
maries = employees["First Name"] == "Maria" # аналог строки выше

employees[maries]
# Out:
#     First Name  Gender Start Date  Salary   Mgmt          Team
# 2        Maria  Female        NaT  130590  False       Finance
# 198      Maria  Female 1990-12-27   36067   True       Product
# 815      Maria     NaN 1986-01-18  106562  False            HR
# 844      Maria     NaN 1985-06-19  148857  False         Legal
# 936      Maria  Female 2003-03-14   96250  False  Business Dev
# 984      Maria  Female 2011-10-15   43455  False   Engineering

# %%
employees["Team"] != "Finance"
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 996     False
# 997      True
# 998      True
# 999      True
# 1000     True
# Name: Team, Length: 1001, dtype: bool

# %%
employees[employees["Team"] != "Finance"]
# Out:
#      First Name  Gender Start Date  Salary   Mgmt          Team
# 0       Douglas    Male 1993-08-06       0   True     Marketing
# 1        Thomas    Male 1996-03-31   61933   True           NaN
# 4         Larry    Male 1998-01-24  101004   True            IT
# 5        Dennis    Male 1987-04-18  115163  False         Legal
# 6          Ruby  Female 1987-08-17   65476   True       Product
# ...         ...     ...        ...     ...    ...           ...
# 995       Henry     NaN 2014-11-23  132483  False  Distribution
# 997     Russell    Male 2013-05-20   96914  False       Product
# 998       Larry    Male 2013-04-20   60500  False  Business Dev
# 999      Albert    Male 2012-05-15  129949   True         Sales
# 1000        NaN     NaN        NaT       0   True           NaN
#
# [899 rows x 6 columns]

# %%
employees[employees["Mgmt"]].head() # так как столбец "Mgmt" уже булев, то нет смысла проверять его на условие. со старта в Pandas без явного указания будет True.
# Out:
#   First Name  Gender Start Date  Salary  Mgmt       Team
# 0    Douglas    Male 1993-08-06       0  True  Marketing
# 1     Thomas    Male 1996-03-31   61933  True        NaN
# 3      Jerry     NaN 2005-03-04  138705  True    Finance
# 4      Larry    Male 1998-01-24  101004  True         IT
# 6       Ruby  Female 1987-08-17   65476  True    Product

# %%
high_earners = employees["Salary"] > 100000
high_earners.head()
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# Name: Salary, dtype: bool

# %%
employees[high_earners].head()
# Out:
#   First Name  Gender Start Date  Salary   Mgmt          Team
# 2      Maria  Female        NaT  130590  False       Finance
# 3      Jerry     NaN 2005-03-04  138705   True       Finance
# 4      Larry    Male 1998-01-24  101004   True            IT
# 5     Dennis    Male 1987-04-18  115163  False         Legal
# 9    Frances  Female 2002-08-08  139852   True  Business Dev

# %% [markdown]
# """---5.3 ФИЛЬТРАЦИЯ ПО НЕСКОЛЬКИМ УСЛОВИЯМ---"""
#
# """---5.3.1 Условие И---"""

# %%
is_female = employees["Gender"] == "Female"

# %%
in_biz_dev = employees["Team"] == "Business Dev"

# %%
employees[is_female & in_biz_dev].head() # & - оператор "И"
# Out:
#    First Name  Gender Start Date  Salary   Mgmt          Team
# 9     Frances  Female 2002-08-08  139852   True  Business Dev
# 33       Jean  Female 1993-12-18  119082  False  Business Dev
# 36     Rachel  Female 2009-02-16  142032  False  Business Dev
# 38  Stephanie  Female 1986-09-13   36844   True  Business Dev
# 61     Denise  Female 2001-11-06  106862  False  Business Dev

# %%
is_maneger = employees["Mgmt"]

employees[is_female & in_biz_dev & is_maneger].head()
# Out:
#     First Name  Gender Start Date  Salary  Mgmt          Team
# 9      Frances  Female 2002-08-08  139852  True  Business Dev
# 38   Stephanie  Female 1986-09-13   36844  True  Business Dev
# 66       Nancy  Female 2012-12-15  125250  True  Business Dev
# 92       Linda  Female 2000-05-25  119009  True  Business Dev
# 111     Bonnie  Female 1999-12-17   42153  True  Business Dev

# %% [markdown]
# """---5.3.2 Условие ИЛИ---"""

# %%
earning_below_40k = employees["Salary"] < 40000
started_after_2015 = employees["Start Date"] > "2015-01-01"

# %%
employees[earning_below_40k | started_after_2015].tail() # | - оператор "ИЛИ"
# Out:
#      First Name  Gender Start Date  Salary   Mgmt         Team
# 958      Gloria  Female 1987-10-24   39833  False  Engineering
# 964       Bruce    Male 1980-05-07   35802   True        Sales
# 967      Thomas    Male 2016-03-12  105681  False  Engineering
# 989      Justin     NaN 1991-02-10   38344  False        Legal
# 1000        NaN     NaN        NaT       0   True          NaN

# %% [markdown]
# """---5.3.3 Логистическое отрицание---"""

# %%
my_series = pd.Series([True, False, True])
my_series
# Out:
# 0     True
# 1    False
# 2     True
# dtype: bool

# %%
~my_series # меняет булев признак местами. False = True, True = False.
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
employees[employees["Salary"] < 100000].head()
# Out:
#   First Name  Gender Start Date  Salary  Mgmt         Team
# 0    Douglas    Male 1993-08-06       0  True    Marketing
# 1     Thomas    Male 1996-03-31   61933  True          NaN
# 6       Ruby  Female 1987-08-17   65476  True      Product
# 7        NaN  Female 2015-07-20   45906  True      Finance
# 8     Angela  Female 2005-11-22   95570  True  Engineering

# %%
employees[~(employees["Salary"] > 100000)].head() # все, что после "~" нужно помещать в (), чтобы не нарушить послежовательность выполнения операции.
# Out:
#   First Name  Gender Start Date  Salary  Mgmt         Team
# 0    Douglas    Male 1993-08-06       0  True    Marketing
# 1     Thomas    Male 1996-03-31   61933  True          NaN
# 6       Ruby  Female 1987-08-17   65476  True      Product
# 7        NaN  Female 2015-07-20   45906  True      Finance
# 8     Angela  Female 2005-11-22   95570  True  Engineering

# %% [markdown]
# """---5.4 ФИЛЬТРАЦИЯ ПО УСЛОВИЮ---"""
#
# """---5.4.1 Метод isin---"""

# %%
all_star_teams = ["Sales", "Legal", "Marketing"] # набор данных для поиска
on_all_star_teams = employees["Team"].isin(all_star_teams) # поиск объекта Series
employees[on_all_star_teams] # вывод поиска по DataFrame
# Out:
#     First Name  Gender Start Date  Salary   Mgmt       Team
# 0      Douglas    Male 1993-08-06       0   True  Marketing
# 5       Dennis    Male 1987-04-18  115163  False      Legal
# 11       Julie  Female 1997-10-26  102508   True      Legal
# 13        Gary    Male 2008-01-27  109831  False      Sales
# 20        Lois     NaN 1995-04-22   64714   True      Legal
# ..         ...     ...        ...     ...    ...        ...
# 986      Donna  Female 1982-11-26   82871  False  Marketing
# 989     Justin     NaN 1991-02-10   38344  False      Legal
# 991       Rose  Female 2002-08-25  134505   True  Marketing
# 994     George    Male 2013-06-21   98874   True  Marketing
# 999     Albert    Male 2012-05-15  129949   True      Sales
#
# [280 rows x 6 columns]

# %% [markdown]
# """---5.4.2 Метод between---"""

# %%
between_80k_and_90k = employees["Salary"].between(80000, 90000) # объект Series
employees[between_80k_and_90k].head() # применение объекта Series к DataFrame
# Out:
#    First Name  Gender Start Date  Salary   Mgmt         Team
# 19      Donna  Female 2010-07-22   81014  False      Product
# 31      Joyce     NaN 2005-02-20   88657  False      Product
# 35    Theresa  Female 2006-10-10   85182  False        Sales
# 45      Roger    Male 1980-04-17   88010   True        Sales
# 54       Sara  Female 2007-08-15   83677  False  Engineering

# %%
eighties_folk = employees["Start Date"].between("1980-01-01", "1990-01-01")
employees[eighties_folk].head()
# Out:
#    First Name  Gender Start Date  Salary   Mgmt     Team
# 5      Dennis    Male 1987-04-18  115163  False    Legal
# 6        Ruby  Female 1987-08-17   65476   True  Product
# 10     Louise  Female 1980-08-12   63241   True      NaN
# 12    Brandon    Male 1980-12-01  112807   True       HR
# 17      Shawn    Male 1986-12-07  111737  False  Product

# %%
name_starts_with_r = employees["First Name"].between("R", "S")
employees[name_starts_with_r].head()
# Out:
#    First Name  Gender Start Date  Salary   Mgmt          Team
# 6        Ruby  Female 1987-08-17   65476   True       Product
# 36     Rachel  Female 2009-02-16  142032  False  Business Dev
# 45      Roger    Male 1980-04-17   88010   True         Sales
# 67     Rachel  Female 1999-08-16   51178   True       Finance
# 78      Robin  Female 1983-06-04  114797   True         Sales

# %% [markdown]
# """---5.4.3 Методы isnull и notnull---"""

# %%
employees.head() # NaT - "не значение времени"
# Out:
#   First Name  Gender Start Date  Salary   Mgmt       Team
# 0    Douglas    Male 1993-08-06       0   True  Marketing
# 1     Thomas    Male 1996-03-31   61933   True        NaN
# 2      Maria  Female        NaT  130590  False    Finance
# 3      Jerry     NaN 2005-03-04  138705   True    Finance
# 4      Larry    Male 1998-01-24  101004   True         IT

# %%
employees["Team"].isnull().head() # проверка на пустае значения
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# Name: Team, dtype: bool

# %%
employees["Start Date"].isnull().head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: Start Date, dtype: bool

# %%
employees["Team"].notnull().head() # проверка на не пустые значения
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# Name: Team, dtype: bool

# %%
~(employees["Team"].isnull().head()) # обратная проверка на пустае значения (аналог "notnull")
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# Name: Team, dtype: bool

# %%
no_team = employees["Team"].isnull()

employees[no_team].head()
# Out:
#    First Name  Gender Start Date  Salary   Mgmt Team
# 1      Thomas    Male 1996-03-31   61933   True  NaN
# 10     Louise  Female 1980-08-12   63241   True  NaN
# 23        NaN    Male 2012-06-14  125792   True  NaN
# 32        NaN    Male 1998-08-21  122340   True  NaN
# 91      James     NaN 2005-01-26  128771  False  NaN

# %%
has_name = employees["First Name"].notnull()

employees[has_name].tail()
# Out:
#     First Name Gender Start Date  Salary   Mgmt          Team
# 995      Henry    NaN 2014-11-23  132483  False  Distribution
# 996    Phillip   Male 1984-01-31   42392  False       Finance
# 997    Russell   Male 2013-05-20   96914  False       Product
# 998      Larry   Male 2013-04-20   60500  False  Business Dev
# 999     Albert   Male 2012-05-15  129949   True         Sales

# %%
"""---5.4.4 Обработка пустых значений---"""
# Out:
# '---5.4.4 Обработка пустых значений---'

# %%
employees = pd.read_csv(
    "employees.csv",
    parse_dates=["Start Date"]
)

employees
# Out:
# /tmp/ipykernel_4248/2426245998.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   employees = pd.read_csv(
#      First Name  Gender Start Date    Salary   Mgmt          Team
# 0       Douglas    Male 1993-08-06       NaN   True     Marketing
# 1        Thomas    Male 1996-03-31   61933.0   True           NaN
# 2         Maria  Female        NaT  130590.0  False       Finance
# 3         Jerry     NaN 2005-03-04  138705.0   True       Finance
# 4         Larry    Male 1998-01-24  101004.0   True            IT
# ...         ...     ...        ...       ...    ...           ...
# 996     Phillip    Male 1984-01-31   42392.0  False       Finance
# 997     Russell    Male 2013-05-20   96914.0  False       Product
# 998       Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999      Albert    Male 2012-05-15  129949.0   True         Sales
# ...

# %%
employees.dropna() # удаляем строки в которых есть минимум одно пропущенное значение
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 4        Larry    Male 1998-01-24  101004.0   True            IT
# 5       Dennis    Male 1987-04-18  115163.0  False         Legal
# 6         Ruby  Female 1987-08-17   65476.0   True       Product
# 8       Angela  Female 2005-11-22   95570.0   True   Engineering
# 9      Frances  Female 2002-08-08  139852.0   True  Business Dev
# ..         ...     ...        ...       ...    ...           ...
# 994     George    Male 2013-06-21   98874.0   True     Marketing
# 996    Phillip    Male 1984-01-31   42392.0  False       Finance
# 997    Russell    Male 2013-05-20   96914.0  False       Product
# 998      Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999     Albert    Male 2012-05-15  129949.0   True         Sales
#
# [761 rows x 6 columns]

# %%
employees.dropna(how="all").tail() # how = all - удаление строк, в которых все значения = пропущенные
# Out:
#     First Name Gender Start Date    Salary   Mgmt          Team
# 995      Henry    NaN 2014-11-23  132483.0  False  Distribution
# 996    Phillip   Male 1984-01-31   42392.0  False       Finance
# 997    Russell   Male 2013-05-20   96914.0  False       Product
# 998      Larry   Male 2013-04-20   60500.0  False  Business Dev
# 999     Albert   Male 2012-05-15  129949.0   True         Sales

# %%
employees.dropna(subset=["Gender"]).tail() # удаляем пустые значения из конкретного столбца
# Out:
#     First Name Gender Start Date    Salary   Mgmt          Team
# 994     George   Male 2013-06-21   98874.0   True     Marketing
# 996    Phillip   Male 1984-01-31   42392.0  False       Finance
# 997    Russell   Male 2013-05-20   96914.0  False       Product
# 998      Larry   Male 2013-04-20   60500.0  False  Business Dev
# 999     Albert   Male 2012-05-15  129949.0   True         Sales

# %%
employees.dropna(subset=["Start Date", "Salary"]).head() # удаляем пустые значения из нескольких указанных столбцов
# Out:
#   First Name  Gender Start Date    Salary   Mgmt     Team
# 1     Thomas    Male 1996-03-31   61933.0   True      NaN
# 3      Jerry     NaN 2005-03-04  138705.0   True  Finance
# 4      Larry    Male 1998-01-24  101004.0   True       IT
# 5     Dennis    Male 1987-04-18  115163.0  False    Legal
# 6       Ruby  Female 1987-08-17   65476.0   True  Product

# %%
employees.dropna(thresh=4).head() # удаляем строку, только если в ней меньше чем 4ре заполненых значения. Если заполненных ≥ 4 — строка остаётся.
# Out:
#   First Name  Gender Start Date    Salary   Mgmt       Team
# 0    Douglas    Male 1993-08-06       NaN   True  Marketing
# 1     Thomas    Male 1996-03-31   61933.0   True        NaN
# 2      Maria  Female        NaT  130590.0  False    Finance
# 3      Jerry     NaN 2005-03-04  138705.0   True    Finance
# 4      Larry    Male 1998-01-24  101004.0   True         IT

# %% [markdown]
# """---5.5 РЕШЕНИЕ ПРОБЛЕМ ДУБЛИКАТОВ---"""
#
# """---5.5.1 Метод duplicated---"""

# %%
employees["Team"].head()
# Out:
# 0    Marketing
# 1          NaN
# 2      Finance
# 3      Finance
# 4           IT
# Name: Team, dtype: object

# %%
employees["Team"].duplicated().head() # отмечаем первое вхождение дубликата как False, следующие как True
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# Name: Team, dtype: bool

# %%
employees["Team"].duplicated(keep="first").head() # keep - указывает, какое из дублирующих значений оставлять. first - первое из дубликата = не дубликат
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# Name: Team, dtype: bool

# %%
employees["Team"].duplicated(keep="last") # keep - указывает, какое из дублирующих значений оставлять. last - последнее вхождение = не дубликат
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 996     False
# 997     False
# 998     False
# 999     False
# 1000    False
# Name: Team, Length: 1001, dtype: bool

# %%
(~employees["Team"].duplicated()).head()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# Name: Team, dtype: bool

# %%
first_one_in_team = ~employees["Team"].duplicated()

employees[first_one_in_team]
# Out:
#    First Name  Gender Start Date    Salary   Mgmt          Team
# 0     Douglas    Male 1993-08-06       NaN   True     Marketing
# 1      Thomas    Male 1996-03-31   61933.0   True           NaN
# 2       Maria  Female        NaT  130590.0  False       Finance
# 4       Larry    Male 1998-01-24  101004.0   True            IT
# 5      Dennis    Male 1987-04-18  115163.0  False         Legal
# 6        Ruby  Female 1987-08-17   65476.0   True       Product
# 8      Angela  Female 2005-11-22   95570.0   True   Engineering
# 9     Frances  Female 2002-08-08  139852.0   True  Business Dev
# 12    Brandon    Male 1980-12-01  112807.0   True            HR
# 13       Gary    Male 2008-01-27  109831.0  False         Sales
# 40    Michael    Male 2008-10-10   99283.0   True  Distribution
